# %%
import pandas as pd
df = pd.read_csv("../data/raw/House_Prices.csv")
df = df.iloc[:1460].copy()

# %%
df = df.drop(columns="Id")
df["MSSubClass"] = df["MSSubClass"].astype("str")

# %%
df.shape
# Out:
# (1460, 80)

# %% [markdown]
# the data contains 2919 houses and 80 feature

# %%
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %% [markdown]
# the dataset contains many features describing the house : its locations , size , quality, age , rooms, garage, outdoor areas and sate info
# the target is SatePrice

# %%
pd.set_option('display.max_rows', None)
df.dtypes
# Out:
# MSSubClass           str
# MSZoning             str
# LotFrontage      float64
# LotArea            int64
# Street               str
# Alley                str
# LotShape             str
# LandContour          str
# Utilities            str
# LotConfig            str
# LandSlope            str
# Neighborhood         str
# Condition1           str
# Condition2           str
# BldgType             str
# HouseStyle           str
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle            str
# RoofMatl             str
# Exterior1st          str
# Exterior2nd          str
# MasVnrType           str
# MasVnrArea       float64
# ExterQual            str
# ExterCond            str
# Foundation           str
# BsmtQual             str
# BsmtCond             str
# BsmtExposure         str
# BsmtFinType1         str
# BsmtFinSF1       float64
# BsmtFinType2         str
# BsmtFinSF2       float64
# BsmtUnfSF        float64
# ...

# %% [markdown]
# the df contains both numirical and categorical features

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   str
#  1   MSZoning       1460 non-null   str
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   str
#  5   Alley          91 non-null     str
#  6   LotShape       1460 non-null   str
#  7   LandContour    1460 non-null   str
#  8   Utilities      1460 non-null   str
#  9   LotConfig      1460 non-null   str
#  10  LandSlope      1460 non-null   str
#  11  Neighborhood   1460 non-null   str
#  12  Condition1     1460 non-null   str
#  13  Condition2     1460 non-null   str
#  14  BldgType       1460 non-null   str
#  15  HouseStyle     1460 non-null   str
#  16  OverallQual    1460 non-null   int64
#  17  OverallCond    1460 non-null   int64
#  18  YearBuilt      1460 non-null   int64
# ...

# %% [markdown]
# several columns contain missing values such : lotfrontage and alley

# %%
df.isna().sum()
# Out:
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType        872
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# CentralAir          0
# ...

# %%
missing_values = df.isna().sum()

missing_values[missing_values > 0].sort_values(ascending=False)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# BsmtExposure      38
# BsmtFinType2      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# Electrical         1
# dtype: int64

# %% [markdown]
# the datasets contains many missing values columns: some has very high percentage of missing data: poolQC , miscfeature , alley , fence ... others has a low percentage of missing date different strategies will be needed during data processing

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# no duplicateds rows found in the data

# %%
df.describe()
# Out:
#        LotFrontage        LotArea  OverallQual  OverallCond    YearBuilt  \
# count  1201.000000    1460.000000  1460.000000  1460.000000  1460.000000
# mean     70.049958   10516.828082     6.099315     5.575342  1971.267808
# std      24.284752    9981.264932     1.382997     1.112799    30.202904
# min      21.000000    1300.000000     1.000000     1.000000  1872.000000
# 25%      59.000000    7553.500000     5.000000     5.000000  1954.000000
# 50%      69.000000    9478.500000     6.000000     5.000000  1973.000000
# 75%      80.000000   11601.500000     7.000000     6.000000  2000.000000
# max     313.000000  215245.000000    10.000000     9.000000  2010.000000
#
#        YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  ...  \
# count   1460.000000  1452.000000  1460.000000  1460.000000  1460.000000  ...
# mean    1984.865753   103.685262   443.639726    46.549315   567.240411  ...
# std       20.645407   181.066207   456.098091   161.319273   441.866955  ...
# ...

# %% [markdown]
# The numerical features have very different ranges: Some columns show large extreme values, such as LotArea, which may indicate outliers. SalePrice ranges from 34 900 to 755 000, with a median around 176 735

# %%
numeric_cols = df.select_dtypes(include="number").columns
categorical_cols = df.select_dtypes(exclude="number").columns

# %%
numeric_cols
#len(numeric_cols)
# Out:
# Index(['LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#        'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt',
#        'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='str')

# %% [markdown]
# the dataset contains 38 numirical columns , most represent numirical values , but some are categorical codes and may require special handling

# %%
categorical_cols
#len(categorical_cols)
# Out:
# Index(['MSSubClass', 'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
#        'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC',
#        'Fence', 'MiscFeature', 'SaleType', 'SaleCondition'],
#       dtype='str')

# %% [markdown]
# The dataset contains 43 categorical columns. Most of them will need to be encoded into numerical values before they can be used by the Machine Learning models

# %%
df["SalePrice"].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# SalePrice has an average value of about 180,053 and a median of about 176,735. Prices range from 34,900 to 755,000, which shows a wide spread and suggests the presence of some high-price extreme values.

# %%
for col in categorical_cols:
    print(col, df[col].unique()[:20])
# Out:
# MSSubClass <ArrowStringArray>
# [ '60',  '20',  '70',  '50', '190',  '45',  '90', '120',  '30',  '85',  '80',
#  '160',  '75', '180',  '40']
# Length: 15, dtype: str
# MSZoning <ArrowStringArray>
# ['RL', 'RM', 'C (all)', 'FV', 'RH']
# Length: 5, dtype: str
# Street <ArrowStringArray>
# ['Pave', 'Grvl']
# Length: 2, dtype: str
# Alley <ArrowStringArray>
# [nan, 'Grvl', 'Pave']
# Length: 3, dtype: str
# LotShape <ArrowStringArray>
# ['Reg', 'IR1', 'IR2', 'IR3']
# Length: 4, dtype: str
# LandContour <ArrowStringArray>
# ['Lvl', 'Bnk', 'Low', 'HLS']
# Length: 4, dtype: str
# Utilities <ArrowStringArray>
# ['AllPub', 'NoSeWa']
# Length: 2, dtype: str
# LotConfig <ArrowStringArray>
# ['Inside', 'FR2', 'Corner', 'CulDSac', 'FR3']
# Length: 5, dtype: str
# LandSlope <ArrowStringArray>
# ['Gtl', 'Mod', 'Sev']
# Length: 3, dtype: str
# Neighborhood <ArrowStringArray>
# ['CollgCr', 'Veenker', 'Crawfor', 'NoRidge', 'Mitchel', 'Somerst',  'NWAmes',
# ...

# %% [markdown]
# No obvious inconsistencies were found in the categorical values. Most values appear to use consistent category codes. Some categorical columns contain missing values NaN, which will be handled during preprocessing

# %%
df[numeric_cols].describe().T
# Out:
#                 count           mean           std      min        25%  \
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# TotalBsmtSF    1460.0    1057.429452    438.705324      0.0     795.75
# 1stFlrSF       1460.0    1162.626712    386.587738    334.0     882.00
# ...

# %% [markdown]
# Several numerical features contain extreme values compared with their median, which may indicate possible outliers. Examples include LotArea, GrLivArea, MiscVal, and SalePrice. GarageYrBlt also contains a suspicious maximum value of 2207, which should be investigated during preprocessing.

# %%
df["SalePrice"].sort_values().head()
# Out:
# 495    34900.0
# 916    35311.0
# 968    37900.0
# 533    39300.0
# 30     40000.0
# Name: SalePrice, dtype: float64

# %% [markdown]
# The lowest house prices range from 34,900 to 40,000. These values are much lower than the median price 176,735, so they should be kept in mind as possible low-end outliers, but they are not automatically errors.

# %%
df["SalePrice"].sort_values(ascending=False).head()
# Out:
# 691     755000.0
# 1182    745000.0
# 1169    625000.0
# 898     611657.0
# 803     582933.0
# Name: SalePrice, dtype: float64

# %% [markdown]
# The highest house prices range from 582 933 to 755 000. These values are much higher than the median price, so they may represent high-end outliers and should be analyzed further before deciding whether to keep, transform, or remove them.
